# %% [markdown]
# # Audio Training in 5 Cells (Single Config File)
# This notebook uses only one config: `configs/master_config.json`.
#
# Rules:
# - No extra config files are created.
# - Training/eval/export always read from `configs/master_config.json`.
# - To change parameters, edit that one file directly, then rerun cells 2-5.
#
# Decision rule:
# - Accept model if `F1_DEFECT >= 0.70` and `RECALL_DEFECT >= 0.80` on your evaluation script.
# - Otherwise improve data quality/split policy first, then revisit parameters.

# %%
import json
import os
import shlex
import subprocess
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd()
PYTHON_BIN = sys.executable
RUN_CFG = Path('configs/master_config.json')

def run_live(cmd, cwd=None):
    cmd = [str(c) for c in cmd]
    print('$ ' + ' '.join(shlex.quote(c) for c in cmd))
    env = os.environ.copy()
    env['PYTHONUNBUFFERED'] = '1'
    p = subprocess.Popen(
        cmd,
        cwd=str(cwd or PROJECT_ROOT),
        env=env,
        stdout=subprocess.PIPE,
        stderr=subprocess.STDOUT,
        text=True,
        bufsize=1,
    )
    assert p.stdout is not None
    for line in p.stdout:
        print(line, end='')
    rc = p.wait()
    print(f'\n[exit_code={rc}]')
    if rc != 0:
        raise subprocess.CalledProcessError(rc, cmd)

with open(RUN_CFG) as f:
    cfg = json.load(f)

t = cfg['audio']['training']
mil = t.get('sequence_mil', {})

print(f'Python: {PYTHON_BIN}')
print(f'Using single config: {RUN_CFG.resolve()}')
print('Current params from master_config.json:')
print({
    'task': t.get('task'),
    'train_fraction': t.get('train_fraction'),
    'num_epochs': t.get('num_epochs'),
    'patience': t.get('patience'),
    'lr': t.get('lr'),
    'checkpoint_dir': t.get('checkpoint_dir'),
    'mil_enabled': mil.get('enabled'),
    'topk_ratio_pos': mil.get('topk_ratio_pos'),
    'topk_ratio_neg': mil.get('topk_ratio_neg'),
    'eval_pool_ratio': mil.get('eval_pool_ratio'),
    'auto_threshold': mil.get('auto_threshold'),
    'threshold': mil.get('threshold'),
    'good_window_weight': mil.get('good_window_weight'),
})
# Out:
# Python: /home/alolli/miniconda3/envs/therness_env/bin/python
# Using single config: /home/alolli/src/malto/hackathon/therness-hackaton-2026-polito/configs/master_config.json
# Current params from master_config.json:
# {'task': 'binary', 'train_fraction': 0.75, 'num_epochs': 45, 'patience': 10, 'lr': 0.0003, 'checkpoint_dir': 'checkpoints/audio', 'mil_enabled': True, 'topk_ratio_pos': 0.05, 'topk_ratio_neg': 0.2, 'eval_pool_ratio': 0.05, 'auto_threshold': True, 'threshold': 0.5, 'good_window_weight': 0.25}

# %%
import shutil

cfg_now = json.load(open(RUN_CFG))
ckpt_dir = Path(cfg_now['audio']['training']['checkpoint_dir'])
RESET_FROM_SCRATCH = True

if RESET_FROM_SCRATCH and ckpt_dir.exists():
    print(f'Removing old checkpoints: {ckpt_dir.resolve()}')
    shutil.rmtree(ckpt_dir)
    print('Old checkpoints removed.')
elif RESET_FROM_SCRATCH:
    print(f'No existing checkpoint dir to remove: {ckpt_dir.resolve()}')

train_cmd = [PYTHON_BIN, '-u', '-m', 'audio.run_audio', '--config', str(RUN_CFG)]
run_live(train_cmd)
# Out:
# $ /home/alolli/miniconda3/envs/therness_env/bin/python -u -m audio.run_audio --config configs/master_config.json
# Device: cuda
#
# Total weld files: 1163
# File label distribution (binary): {'defect': 617, 'good_weld': 546}
# Split strategy: stratified
# Train welds: 930 | Val welds: 233
# File split stats | train={ defect: 493 (53.0%), good_weld: 437 (47.0%) } | val={ defect: 124 (53.2%), good_weld: 109 (46.8%) }
# Train files: 930 | Val files: 233
# Classes (2): {'defect': 0, 'good_weld': 1}
# DataLoader stats | train_batches=117 | val_batches=30 | batch_size=8
# MIL mode enabled | topk_ratio_pos=0.05 | topk_ratio_neg=0.2 | eval_pool_ratio=0.05 | auto_threshold=True | threshold=0.5 | good_window_weight=0.25
# Model parameters: 185,698
# LR schedule: base_lr=0.0003 | warmup_steps=526/5265 (10.0%) | plateau_factor=0.5 | plateau_patience=3
# Config saved to checkpoints/audio/config.json
#
# Epoch 1/45
# ----------------------------------------
#
# Training (MIL):   0%|          | 0/117 [00:00<?, ?it/s]
# Training (MIL):   0%|          | 0/117 [00:00<?, ?it/s, loss=1.14]
# Training (MIL):   1%|          | 1/117 [00:00<01:07,  1.71it/s, loss=1.14]
# Training (MIL):   1%|          | 1/117 [00:00<01:07,  1.71it/s, loss=1.33]
# Training (MIL):   1%|          | 1/117 [00:00<01:07,  1.71it/s, loss=1.39]
# Training (MIL):   1%|          | 1/117 [00:00<01:07,  1.71it/s, loss=1.34]
# Training (MIL):   1%|          | 1/117 [00:00<01:07,  1.71it/s, loss=1.25]
# Training (MIL):   1%|          | 1/117 [00:00<01:07,  1.71it/s, loss=1.27]
# Training (MIL):   5%|▌         | 6/117 [00:00<00:10, 10.77it/s, loss=1.27]
# Training (MIL):   5%|▌         | 6/117 [00:00<00:10, 10.77it/s, loss=1.25]
# Training (MIL):   5%|▌         | 6/117 [00:00<00:10, 10.77it/s, loss=1.29]
# Training (MIL):   5%|▌         | 6/117 [00:00<00:10, 10.77it/s, loss=1.32]
# Training (MIL):   5%|▌         | 6/117 [00:00<00:10, 10.77it/s, loss=1.3]
# Training (MIL):   5%|▌         | 6/117 [00:00<00:10, 10.77it/s, loss=1.28]
# Training (MIL):   9%|▉         | 11/117 [00:00<00:05, 18.27it/s, loss=1.28]
# Training (MIL):   9%|▉         | 11/117 [00:00<00:05, 18.27it/s, loss=1.29]
# Training (MIL):   9%|▉         | 11/117 [00:00<00:05, 18.27it/s, loss=1.31]
# Training (MIL):   9%|▉         | 11/117 [00:00<00:05, 18.27it/s, loss=1.34]
# Training (MIL):   9%|▉         | 11/117 [00:00<00:05, 18.27it/s, loss=1.32]
# Training (MIL):   9%|▉         | 11/117 [00:00<00:05, 18.27it/s, loss=1.33]
# Training (MIL):  14%|█▎        | 16/117 [00:00<00:04, 24.97it/s, loss=1.33]
# Training (MIL):  14%|█▎        | 16/117 [00:00<00:04, 24.97it/s, loss=1.32]
# Training (MIL):  14%|█▎        | 16/117 [00:00<00:04, 24.97it/s, loss=1.34]
# Training (MIL):  14%|█▎        | 16/117 [00:00<00:04, 24.97it/s, loss=1.33]
# Training (MIL):  14%|█▎        | 16/117 [00:01<00:04, 24.97it/s, loss=1.32]
# Training (MIL):  14%|█▎        | 16/117 [00:01<00:04, 24.97it/s, loss=1.33]
# Training (MIL):  18%|█▊        | 21/117 [00:01<00:03, 30.42it/s, loss=1.33]
# Training (MIL):  18%|█▊        | 21/117 [00:01<00:03, 30.42it/s, loss=1.32]
# Training (MIL):  18%|█▊        | 21/117 [00:01<00:03, 30.42it/s, loss=1.31]
# Training (MIL):  18%|█▊        | 21/117 [00:01<00:03, 30.42it/s, loss=1.31]
# Training (MIL):  18%|█▊        | 21/117 [00:01<00:03, 30.42it/s, loss=1.31]
# Training (MIL):  18%|█▊        | 21/117 [00:01<00:03, 30.42it/s, loss=1.31]
# Training (MIL):  22%|██▏       | 26/117 [00:01<00:02, 34.68it/s, loss=1.31]
# Training (MIL):  22%|██▏       | 26/117 [00:01<00:02, 34.68it/s, loss=1.32]
# Training (MIL):  22%|██▏       | 26/117 [00:01<00:02, 34.68it/s, loss=1.32]
# Training (MIL):  22%|██▏       | 26/117 [00:01<00:02, 34.68it/s, loss=1.32]
# Training (MIL):  22%|██▏       | 26/117 [00:01<00:02, 34.68it/s, loss=1.3]

# Validation (MIL):  80%|████████  | 24/30 [00:00<00:00, 56.38it/s, loss=0.69]
# Validation (MIL):  80%|████████  | 24/30 [00:00<00:00, 56.38it/s, loss=0.69]
# Validation (MIL):  80%|████████  | 24/30 [00:00<00:00, 56.38it/s, loss=0.689]
#
# Train loss: 1.1338 | Val loss: 0.6894 | Val Macro F1: 0.4026 | Val AUC: 0.4669 | Thr: 0.65 | LR: 6.673e-05
# New best model saved (val_f1=0.4026)
# Best snapshot dir: checkpoints/audio/best_models/20260228_034627_ep001_f1_0.4026_vl_0.6894
#
# Epoch 2/45
# ----------------------------------------
#
# Training (MIL):   0%|          | 0/117 [00:00<?, ?it/s]
# Training (MIL):   0%|          | 0/117 [00:00<?, ?it/s, loss=0.839]
# Training (MIL):   1%|          | 1/117 [00:00<00:24,  4.68it/s, loss=0.839]
# Training (MIL):   1%|          | 1/117 [00:00<00:24,  4.68it/s, loss=0.82]
# Training (MIL):   1%|          | 1/117 [00:00<00:24,  4.68it/s, loss=0.84]
# Training (MIL):   1%|          | 1/117 [00:00<00:24,  4.68it/s, loss=0.835]
# Training (MIL):   1%|          | 1/117 [00:00<00:24,  4.68it/s, loss=0.794]
# Training (MIL):   4%|▍         | 5/117 [00:00<00:06, 18.62it/s, loss=0.794]
# Training (MIL):   4%|▍         | 5/117 [00:00<00:06, 18.62it/s, loss=0.822]
# Training (MIL):   4%|▍         | 5/117 [00:00<00:06, 18.62it/s, loss=0.845]
# Training (MIL):   4%|▍         | 5/117 [00:00<00:06, 18.62it/s, loss=0.836]
# Training (MIL):   4%|▍         | 5/117 [00:00<00:06, 18.62it/s, loss=0.839]
# Training (MIL):   4%|▍         | 5/117 [00:00<00:06, 18.62it/s, loss=0.84]
# Training (MIL):   9%|▊         | 10/117 [00:00<00:03, 29.31it/s, loss=0.84]
# Training (MIL):   9%|▊         | 10/117 [00:00<00:03, 29.31it/s, loss=0.854]
# Training (MIL):   9%|▊         | 10/117 [00:00<00:03, 29.31it/s, loss=0.846]
# Training (MIL):   9%|▊         | 10/117 [00:00<00:03, 29.31it/s, loss=0.841]
# Training (MIL):   9%|▊         | 10/117 [00:00<00:03, 29.31it/s, loss=0.835]
# Training (MIL):   9%|▊         | 10/117 [00:00<00:03, 29.31it/s, loss=0.848]
# Training (MIL):  13%|█▎        | 15/117 [00:00<00:02, 35.28it/s, loss=0.848]
# Training (MIL):  13%|█▎        | 15/117 [00:00<00:02, 35.28it/s, loss=0.848]
# Training (MIL):  13%|█▎        | 15/117 [00:00<00:02, 35.28it/s, loss=0.846]
# Training (MIL):  13%|█▎        | 15/117 [00:00<00:02, 35.28it/s, loss=0.839]
# Training (MIL):  13%|█▎        | 15/117 [00:00<00:02, 35.28it/s, loss=0.833]
# Training (MIL):  13%|█▎        | 15/117 [00:00<00:02, 35.28it/s, loss=0.839]
# Training (MIL):  17%|█▋        | 20/117 [00:00<00:02, 38.73it/s, loss=0.839]
# Training (MIL):  17%|█▋        | 20/117 [00:00<00:02, 38.73it/s, loss=0.842]
# Training (MIL):  17%|█▋        | 20/117 [00:00<00:02, 38.73it/s, loss=0.839]
# Training (MIL):  17%|█▋        | 20/117 [00:00<00:02, 38.73it/s, loss=0.835]
# Training (MIL):  17%|█▋        | 20/117 [00:00<00:02, 38.73it/s, loss=0.832]
# Training (MIL):  17%|█▋        | 20/117 [00:00<00:02, 38.73it/s, loss=0.832]
# Training (MIL):  21%|██▏       | 25/117 [00:00<00:02, 41.09it/s, loss=0.832]
# Training (MIL):  21%|██▏       | 25/117 [00:00<00:02, 41.09it/s, loss=0.829]
# Training (MIL):  21%|██▏       | 25/117 [00:00<00:02, 41.09it/s, loss=0.829]

# Training (MIL):  86%|████████▋ | 101/117 [00:02<00:00, 44.91it/s, loss=0.525]
# Training (MIL):  86%|████████▋ | 101/117 [00:02<00:00, 44.91it/s, loss=0.525]
# Training (MIL):  91%|█████████ | 106/117 [00:02<00:00, 44.92it/s, loss=0.525]
# Training (MIL):  91%|█████████ | 106/117 [00:02<00:00, 44.92it/s, loss=0.524]
# Training (MIL):  91%|█████████ | 106/117 [00:02<00:00, 44.92it/s, loss=0.524]
# Training (MIL):  91%|█████████ | 106/117 [00:02<00:00, 44.92it/s, loss=0.526]
# Training (MIL):  91%|█████████ | 106/117 [00:02<00:00, 44.92it/s, loss=0.525]
# Training (MIL):  91%|█████████ | 106/117 [00:02<00:00, 44.92it/s, loss=0.526]
# Training (MIL):  95%|█████████▍| 111/117 [00:02<00:00, 45.49it/s, loss=0.526]
# Training (MIL):  95%|█████████▍| 111/117 [00:02<00:00, 45.49it/s, loss=0.525]
# Training (MIL):  95%|█████████▍| 111/117 [00:02<00:00, 45.49it/s, loss=0.523]
# Training (MIL):  95%|█████████▍| 111/117 [00:02<00:00, 45.49it/s, loss=0.523]
# Training (MIL):  95%|█████████▍| 111/117 [00:02<00:00, 45.49it/s, loss=0.523]
# Training (MIL):  95%|█████████▍| 111/117 [00:02<00:00, 45.49it/s, loss=0.522]
# Training (MIL):  99%|█████████▉| 116/117 [00:02<00:00, 46.66it/s, loss=0.522]
# Training (MIL):  99%|█████████▉| 116/117 [00:02<00:00, 46.66it/s, loss=0.522]
#
#
# Validation (MIL):   0%|          | 0/30 [00:00<?, ?it/s]
# Validation (MIL):   0%|          | 0/30 [00:00<?, ?it/s, loss=0.354]
# Validation (MIL):   3%|▎         | 1/30 [00:00<00:05,  4.93it/s, loss=0.354]
# Validation (MIL):   3%|▎         | 1/30 [00:00<00:05,  4.93it/s, loss=0.405]
# Validation (MIL):   3%|▎         | 1/30 [00:00<00:05,  4.93it/s, loss=0.487]
# Validation (MIL):   3%|▎         | 1/30 [00:00<00:05,  4.93it/s, loss=0.516]
# Validation (MIL):   3%|▎         | 1/30 [00:00<00:05,  4.93it/s, loss=0.555]
# Validation (MIL):   3%|▎         | 1/30 [00:00<00:05,  4.93it/s, loss=0.502]
# Validation (MIL):   3%|▎         | 1/30 [00:00<00:05,  4.93it/s, loss=0.467]
# Validation (MIL):   3%|▎         | 1/30 [00:00<00:05,  4.93it/s, loss=0.466]
# Validation (MIL):  27%|██▋       | 8/30 [00:00<00:00, 30.90it/s, loss=0.466]
# Validation (MIL):  27%|██▋       | 8/30 [00:00<00:00, 30.90it/s, loss=0.441]
# Validation (MIL):  27%|██▋       | 8/30 [00:00<00:00, 30.90it/s, loss=0.441]
# Validation (MIL):  27%|██▋       | 8/30 [00:00<00:00, 30.90it/s, loss=0.456]
# Validation (MIL):  27%|██▋       | 8/30 [00:00<00:00, 30.90it/s, loss=0.447]
# Validation (MIL):  27%|██▋       | 8/30 [00:00<00:00, 30.90it/s, loss=0.437]
# Validation (MIL):  27%|██▋       | 8/30 [00:00<00:00, 30.90it/s, loss=0.459]
# Validation (MIL):  27%|██▋       | 8/30 [00:00<00:00, 30.90it/s, loss=0.464]
# Validation (MIL):  50%|█████     | 15/30 [00:00<00:00, 44.73it/s, loss=0.464]
# Validation (MIL):  50%|█████     | 15/30 [00:00<00:00, 44.73it/s, loss=0.463]
# Validation (MIL):  50%|█████     | 15/30 [00:00<00:00, 44.73it/s, loss=0.471]
# Validation (MIL):  50%|█████     | 15/30 [00:00<00:00, 44.73it/s, loss=0.461]
# Validation (MIL):  50%|█████     | 15/30 [00:00<00:00, 44.73it/s, loss=0.454]
# Validation (MIL):  50%|█████     | 15/30 [00:00<00:00, 44.73it/s, loss=0.467]
# Validation (MIL):  50%|█████     | 15/30 [00:00<00:00, 44.73it/s, loss=0.463]
# Validation (MIL):  50%|█████     | 15/30 [00:00<00:00, 44.73it/s, loss=0.463]
# Validation (MIL):  50%|█████     | 15/30 [00:00<00:00, 44.73it/s, loss=0.455]
# Validation (MIL):  77%|███████▋  | 23/30 [00:00<00:00, 54.34it/s, loss=0.455]
# Validation (MIL):  77%|███████▋  | 23/30 [00:00<00:00, 54.34it/s, loss=0.456]
# Validation (MIL):  77%|███████▋  | 23/30 [00:00<00:00, 54.34it/s, loss=0.459]
# Validation (MIL):  77%|███████▋  | 23/30 [00:00<00:00, 54.34it/s, loss=0.463]
# Validation (MIL):  77%|███████▋  | 23/30 [00:00<00:00, 54.34it/s, loss=0.459]
# Validation (MIL):  77%|███████▋  | 23/30 [00:00<00:00, 54.34it/s, loss=0.458]
# Validation (MIL):  77%|███████▋  | 23/30 [00:00<00:00, 54.34it/s, loss=0.458]
# Validation (MIL):  77%|███████▋  | 23/30 [00:00<00:00, 54.34it/s, loss=0.457]
#
# Train loss: 0.5223 | Val loss: 0.4565 | Val Macro F1: 0.6240 | Val AUC: 0.6367 | Thr: 0.75 | LR: 0.00015
# No improvement for 10 epoch(s)
#
# Early stopping at epoch 13
#
# Training complete. Best epoch: 3 (Best Val Macro F1=0.6818)
#
# Best epoch: 3
# Train losses: ['1.1338', '0.7360', '0.5759', '0.5438', '0.5508', '0.5683', '0.5544', '0.5154', '0.5108', '0.5410', '0.5154', '0.5213', '0.5223']
# Val losses:   ['0.6894', '0.5707', '0.5510', '0.5999', '0.5561', '0.6252', '0.6768', '0.9795', '0.6098', '0.4856', '0.3829', '0.4557', '0.4565']
#
# [exit_code=0]

# %%
import torch

ckpt_dir = Path(json.load(open(RUN_CFG))['audio']['training']['checkpoint_dir'])
best_ckpt = ckpt_dir / 'best_model.pt'
print(f'Best checkpoint: {best_ckpt.resolve()}')

if not best_ckpt.exists():
    raise FileNotFoundError(f'best_model.pt not found in {ckpt_dir}')

test_cmd = [
    PYTHON_BIN, '-u', '-m', 'audio.run_audio',
    '--config', str(RUN_CFG),
    '--test_only',
    '--checkpoint', str(best_ckpt),
]
run_live(test_cmd)

try:
    ck = torch.load(best_ckpt, map_location='cpu', weights_only=True)
except TypeError:
    ck = torch.load(best_ckpt, map_location='cpu')

print('--- Best checkpoint stats (single-config run) ---')
print({
    'best_epoch': ck.get('epoch'),
    'val_f1': ck.get('val_f1'),
    'val_auc': ck.get('val_auc'),
    'threshold': ck.get('threshold'),
})
# Out:
# Best checkpoint: /home/alolli/src/malto/hackathon/therness-hackaton-2026-polito/checkpoints/audio_5cells/best_model.pt
# $ /home/alolli/miniconda3/envs/therness_env/bin/python -u -m audio.run_audio --config configs/master_config_5cells.json --test_only --checkpoint checkpoints/audio_5cells/best_model.pt
# Device: cuda
#
# Total weld files: 1163
# File label distribution (binary): {'defect': 617, 'good_weld': 546}
# Split strategy: stratified
# Train welds: 930 | Val welds: 233
# File split stats | train={ defect: 493 (53.0%), good_weld: 437 (47.0%) } | val={ defect: 124 (53.2%), good_weld: 109 (46.8%) }
# Train files: 930 | Val files: 233
# Classes (2): {'defect': 0, 'good_weld': 1}
# DataLoader stats | train_batches=117 | val_batches=30 | batch_size=8
# MIL mode enabled | topk_ratio_pos=0.05 | topk_ratio_neg=0.2 | eval_pool_ratio=0.05 | auto_threshold=True | threshold=0.5 | good_window_weight=0.25
# Model parameters: 185,698
# LR schedule: base_lr=0.0003 | warmup_steps=526/5265 (10.0%) | plateau_factor=0.5 | plateau_patience=3
#
# Validation (MIL):   0%|          | 0/30 [00:00<?, ?it/s]
# Validation (MIL):   0%|          | 0/30 [00:00<?, ?it/s, loss=0.826]
# Validation (MIL):   3%|▎         | 1/30 [00:00<00:10,  2.64it/s, loss=0.826]
# Validation (MIL):   3%|▎         | 1/30 [00:00<00:10,  2.64it/s, loss=0.753]
# Validation (MIL):   3%|▎         | 1/30 [00:00<00:10,  2.64it/s, loss=0.671]
# Validation (MIL):   3%|▎         | 1/30 [00:00<00:10,  2.64it/s, loss=0.603]
# Validation (MIL):   3%|▎         | 1/30 [00:00<00:10,  2.64it/s, loss=0.6]
# Validation (MIL):   3%|▎         | 1/30 [00:00<00:10,  2.64it/s, loss=0.625]
# Validation (MIL):   3%|▎         | 1/30 [00:00<00:10,  2.64it/s, loss=0.657]
# Validation (MIL):   3%|▎         | 1/30 [00:00<00:10,  2.64it/s, loss=0.677]
# Validation (MIL):   3%|▎         | 1/30 [00:00<00:10,  2.64it/s, loss=0.685]
# Validation (MIL):  30%|███       | 9/30 [00:00<00:00, 23.28it/s, loss=0.685]
# Validation (MIL):  30%|███       | 9/30 [00:00<00:00, 23.28it/s, loss=0.682]
# Validation (MIL):  30%|███       | 9/30 [00:00<00:00, 23.28it/s, loss=0.676]
# Validation (MIL):  30%|███       | 9/30 [00:00<00:00, 23.28it/s, loss=0.675]
# Validation (MIL):  30%|███       | 9/30 [00:00<00:00, 23.28it/s, loss=0.668]
# Validation (MIL):  30%|███       | 9/30 [00:00<00:00, 23.28it/s, loss=0.654]
# Validation (MIL):  30%|███       | 9/30 [00:00<00:00, 23.28it/s, loss=0.645]
# Validation (MIL):  30%|███       | 9/30 [00:00<00:00, 23.28it/s, loss=0.65]
# Validation (MIL):  53%|█████▎    | 16/30 [00:00<00:00, 35.73it/s, loss=0.65]
# Validation (MIL):  53%|█████▎    | 16/30 [00:00<00:00, 35.73it/s, loss=0.646]
# Validation (MIL):  53%|█████▎    | 16/30 [00:00<00:00, 35.73it/s, loss=0.652]
# Validation (MIL):  53%|█████▎    | 16/30 [00:00<00:00, 35.73it/s, loss=0.657]
# Validation (MIL):  53%|█████▎    | 16/30 [00:00<00:00, 35.73it/s, loss=0.648]
# Validation (MIL):  53%|█████▎    | 16/30 [00:00<00:00, 35.73it/s, loss=0.653]
# Validation (MIL):  53%|█████▎    | 16/30 [00:00<00:00, 35.73it/s, loss=0.66]
# Validation (MIL):  53%|█████▎    | 16/30 [00:00<00:00, 35.73it/s, loss=0.665]
# Validation (MIL):  53%|█████▎    | 16/30 [00:00<00:00, 35.73it/s, loss=0.666]
# Validation (MIL):  80%|████████  | 24/30 [00:00<00:00, 47.42it/s, loss=0.666]
# Validation (MIL):  80%|████████  | 24/30 [00:00<00:00, 47.42it/s, loss=0.665]
# Validation (MIL):  80%|████████  | 24/30 [00:00<00:00, 47.42it/s, loss=0.669]
# Validation (MIL):  80%|████████  | 24/30 [00:00<00:00, 47.42it/s, loss=0.671]
# Validation (MIL):  80%|████████  | 24/30 [00:00<00:00, 47.42it/s, loss=0.668]
# Validation (MIL):  80%|████████  | 24/30 [00:00<00:00, 47.42it/s, loss=0.668]
# Validation (MIL):  80%|████████  | 24/30 [00:00<00:00, 47.42it/s, loss=0.669]
#
# Val loss: 0.6694
# Val macro F1: 0.7119
# Val accuracy: 0.7124
# Val AUC: 0.7953
# Threshold used: 0.35
#
# [exit_code=0]
# --- Auto-selected from this single run ---
# {'best_epoch': 4, 'val_f1': 0.7119157024488365, 'val_auc': 0.7952796685409883, 'threshold': 0.35}
# Interpretation: without tuning, these are your chosen params + best epoch + best threshold.

# %%
cfg = json.load(open(RUN_CFG))
ckpt_dir = Path(cfg['audio']['training']['checkpoint_dir'])
best_ckpt = ckpt_dir / 'best_model.pt'
deploy_pt = ckpt_dir / 'deploy_single_label.pt'

export_cmd = [
    PYTHON_BIN, '-u', '-m', 'audio.export_deploy_pt',
    '--checkpoint', str(best_ckpt),
    '--output', str(deploy_pt),
]
run_live(export_cmd)

print(f'Deploy artifact ready: {deploy_pt.resolve()}')
print('Optional final check (same as before):')
print('/home/alolli/miniconda3/envs/therness_env/bin/python /tmp/eval_deploy_dataset.py')
